# %% [markdown]
# Group A: Anais, Andreea y Mar
#
# Countries assigned:
#     Argentina, Russia, Colombia, Chile and Spain
#
#
# Option C
#
# 1. Document all steps. Structure your code to keep it cleaned using good practices.
# 2. Collect Coronavirus Data. It is mandatory that in each call, it collects the last updated data.
# 3. Determine and explain if the data is cleaned. If not, then clean it.
# 4. Create an API that returns a Json with the logic explained for your group. The flask server must be executed     running the src/api/server.py file.
# 5. Get the jsons generated from your annexed group and plot it. First, try to connect to the private ip of your     annexed group. If it is not possible because of physical issues, then simply use what they generate copying      it. If your annexed group cannot give you the necessary json, then annotate it, use the json of another group.
# 6. Show different tendencies for each column in your dataset. Show, vertically, the start date and end date of      the alarm state in each plot. If there is no alarm state, then show only the start date.
# 7. Draw the workflow of your program. You can use free tools.
# 8. Per country, which are the columns that are more related find the correlation between columns with the           correlation matrix.
# DONE: 9. Use a different github repository adding all group participants with write permissions. Use that           repository to manage the delivery code and resources. It is mandatory that every student of the group does,      at least,five commits/push.
#
#     10. Answer the questions:
#         a. What position do your countries occupe respect to the number of total infected, total deaths and                 total recoveries?
#         b. What can you conclude about your data study?
#         c. Are there outliers or some rare data?
#
#
#
# Our API must offer data to Group B and receive it from Group F, as follows:
#
#     We have to offer a json(df):
#     - Group A: it must return a json with one key “n_c_averages” that represents
#     the mean of the “new_cases” per day of all of your countries.
#
#
#     We should receive a json(df):
#     - Group F: it must return a json with one key “n_t_averages” that represents the
#     mean of the “new_tests” per day of all your countries.
#
# Option B.... to be continued

# %%
import pandas as pd
import requests
import json

# %%
def jsonlink_df(url_json):
    """
    What it does:
        # This function opens a json in python from a given url/link

    What it needs:
        # The url of the destination file, must be a string.

    What it returns:
        # The opened json as dataframe 
        GITHUB ID: @anaisvh
        """

    r = requests.get(url=url_json)
    json_readed = json.loads(r.text)
    df = pd.DataFrame(json_readed)
    return df

# %%
# se debe importar a traves de la url, para asegurarnos de que los datos importados son actualizados
data_covid = jsonlink_df('https://covid.ourworldindata.org/data/owid-covid-data.json')
data_covid
# Out:
#                             8787.58
# cardiovasc_death_rate                                                  341.01
# diabetes_prevalence                                                      7.11
# handwashing_facilities                                                 94.043
# hospital_beds_per_thousand                                                4.2
# life_expectancy                                                         75.09
# human_development_index                                                 0.755
# data                        [{'date': '2020-03-01', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           1.8
# female_smokers                                                            1.5
# male_smokers                                                             52.1
#
#                                                                           AUS  \
# continent                                                             Oceania
# location                                                            Australia
# population                                                        2.54999e+07
# population_density                                                      3.202
# median_age                                                               37.9
# aged_65_older                                                          15.504
# aged_70_older                                                          10.129
# gdp_per_capita                                                        44648.7
# cardiovasc_death_rate                                                 107.791
# diabetes_prevalence                                                      5.07
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                               3.84
# life_expectancy                                                         83.44
# human_development_index                                                 0.939
# data                        [{'date': '2020-01-26', 'total_cases': 4.0, 'n...
# extreme_poverty                                                           0.5
# female_smokers                                                             13
# male_smokers                                                             16.5
#
#                                                                           AUT  \
# continent                                                              Europe
# location                                                              Austria
# population                                                         9.0064e+06
# population_density                                                    106.749
# median_age                                                               44.4
# aged_65_older                                                          19.202
# aged_70_older                                                          13.748
# gdp_per_capita                                                        45436.7
# cardiovasc_death_rate                                                 145.183
# diabetes_prevalence                                                      6.35
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                               7.37
# life_expectancy                                                         81.54
# human_development_index                                                 0.908
# data                        [{'date': '2020-02-25', 'total_cases': 2.0, 'n...
# extreme_poverty                                                           0.7
# female_smokers                                                           28.4
# male_smokers                                                             30.9
#
#                             ...  \
# continent                   ...
# location                    ...
# population                  ...
# population_density          ...
# median_age                  ...
# aged_65_older               ...
# aged_70_older               ...
# gdp_per_capita              ...
# cardiovasc_death_rate       ...
# diabetes_prevalence         ...
# handwashing_facilities      ...
# hospital_beds_per_thousand  ...
# life_expectancy             ...
# human_development_index     ...
# data                        ...
# extreme_poverty             ...
# female_smokers              ...
# male_smokers                ...
#
#                                                                           URY  \
# continent                                                       South America
# location                                                              Uruguay
# population                                                        3.47373e+06
# population_density                                                     19.751
# median_age                                                               35.6
# aged_65_older                                                          14.655
# aged_70_older                                                          10.361
# gdp_per_capita                                                        20551.4
# cardiovasc_death_rate                                                 160.708
# diabetes_prevalence                                                      6.93
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                2.8
# life_expectancy                                                         77.91
# human_development_index                                                 0.804
# data                        [{'date': '2020-03-13', 'total_cases': 4.0, 'n...
# extreme_poverty                                                           0.1
# female_smokers                                                             14
# male_smokers                                                             19.9
#
#                                                                           UZB  \
# continent                                                                Asia
# location                                                           Uzbekistan
# population                                                        3.34692e+07
# population_density                                                     76.134
# median_age                                                               28.2
# aged_65_older                                                           4.469
# aged_70_older                                                           2.873
# gdp_per_capita                                                         6253.1
# cardiovasc_death_rate                                                 724.417
# diabetes_prevalence                                                      7.57
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                  4
# life_expectancy                                                         71.72
# human_development_index                                                  0.71
# data                        [{'date': '2020-03-15', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            1.3
# male_smokers                                                             24.7
#
#                                                                           VUT  \
# continent                                                             Oceania
# location                                                              Vanuatu
# population                                                             307150
# population_density                                                     22.662
# median_age                                                               23.1
# aged_65_older                                                           4.394
# aged_70_older                                                            2.62
# gdp_per_capita                                                        2921.91
# cardiovasc_death_rate                                                   546.3
# diabetes_prevalence                                                     12.02
# handwashing_facilities                                                 25.209
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         70.47
# human_development_index                                                 0.603
# data                        [{'date': '2020-11-10', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          13.2
# female_smokers                                                            2.8
# male_smokers                                                             34.5
#
#                                                                           VAT  \
# continent                                                              Europe
# location                                                              Vatican
# population                                                                809
# population_density                                                        NaN
# median_age                                                                NaN
# aged_65_older                                                             NaN
# aged_70_older                                                             NaN
# gdp_per_capita                                                            NaN
# cardiovasc_death_rate                                                     NaN
# diabetes_prevalence                                                       NaN
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                NaN
# life_expectancy                                                         75.12
# human_development_index                                                   NaN
# data                        [{'date': '2020-03-06', 'total_cases': 1.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           VEN  \
# continent                                                       South America
# location                                                            Venezuela
# population                                                        2.84359e+07
# population_density                                                     36.253
# median_age                                                                 29
# aged_65_older                                                           6.614
# aged_70_older                                                           3.915
# gdp_per_capita                                                          16745
# cardiovasc_death_rate                                                  204.85
# diabetes_prevalence                                                      6.47
# handwashing_facilities                                                    NaN
# hospital_beds_per_thousand                                                0.8
# life_expectancy                                                         72.06
# human_development_index                                                 0.761
# data                        [{'date': '2020-03-14', 'total_cases': 2.0, 'n...
# extreme_poverty                                                           NaN
# female_smokers                                                            NaN
# male_smokers                                                              NaN
#
#                                                                           VNM  \
# continent                                                                Asia
# location                                                              Vietnam
# population                                                        9.73386e+07
# population_density                                                    308.127
# median_age                                                               32.6
# aged_65_older                                                            7.15
# aged_70_older                                                           4.718
# gdp_per_capita                                                        6171.88
# cardiovasc_death_rate                                                 245.465
# diabetes_prevalence                                                         6
# handwashing_facilities                                                 85.847
# hospital_beds_per_thousand                                                2.6
# life_expectancy                                                          75.4
# human_development_index                                                 0.694
# data                        [{'date': '2020-01-23', 'total_cases': 2.0, 'n...
# extreme_poverty                                                             2
# female_smokers                                                              1
# male_smokers                                                             45.9
#
#                                                                      OWID_WRL  \
# continent                                                                 NaN
# location                                                                World
# population                                                         7.7948e+09
# population_density                                                     58.045
# median_age                                                               30.9
# aged_65_older                                                           8.696
# aged_70_older                                                           5.355
# gdp_per_capita                                                        15469.2
# cardiovasc_death_rate                                                  233.07
# diabetes_prevalence                                                      8.51
# handwashing_facilities                                                  60.13
# hospital_beds_per_thousand                                              2.705
# life_expectancy                                                         72.58
# human_development_index                                                   NaN
# data                        [{'date': '2020-01-22', 'total_cases': 557.0, ...
# extreme_poverty                                                            10
# female_smokers                                                          6.434
# male_smokers                                                           34.635
#
#                                                                           YEM  \
# continent                                                                Asia
# location                                                                Yemen
# population                                                         2.9826e+07
# population_density                                                     53.508
# median_age                                                               20.3
# aged_65_older                                                           2.922
# aged_70_older                                                           1.583
# gdp_per_capita                                                        1479.15
# cardiovasc_death_rate                                                 495.003
# diabetes_prevalence                                                      5.35
# handwashing_facilities                                                 49.542
# hospital_beds_per_thousand                                                0.7
# life_expectancy                                                         66.12
# human_development_index                                                 0.452
# data                        [{'date': '2020-04-10', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          18.8
# female_smokers                                                            7.6
# male_smokers                                                             29.2
#
#                                                                           ZMB  \
# continent                                                              Africa
# location                                                               Zambia
# population                                                         1.8384e+07
# population_density                                                     22.995
# median_age                                                               17.7
# aged_65_older                                                            2.48
# aged_70_older                                                           1.542
# gdp_per_capita                                                        3689.25
# cardiovasc_death_rate                                                 234.499
# diabetes_prevalence                                                      3.94
# handwashing_facilities                                                 13.938
# hospital_beds_per_thousand                                                  2
# life_expectancy                                                         63.89
# human_development_index                                                 0.588
# data                        [{'date': '2020-03-18', 'total_cases': 2.0, 'n...
# extreme_poverty                                                          57.5
# female_smokers                                                            3.1
# male_smokers                                                             24.7
#
#                                                                           ZWE
# continent                                                              Africa
# location                                                             Zimbabwe
# population                                                        1.48629e+07
# population_density                                                     42.729
# median_age                                                               19.6
# aged_65_older                                                           2.822
# aged_70_older                                                           1.882
# gdp_per_capita                                                        1899.78
# cardiovasc_death_rate                                                 307.846
# diabetes_prevalence                                                      1.82
# handwashing_facilities                                                 36.791
# hospital_beds_per_thousand                                                1.7
# life_expectancy                                                         61.49
# human_development_index                                                 0.535
# data                        [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
# extreme_poverty                                                          21.4
# female_smokers                                                            1.6
# male_smokers                                                             30.7
#
# [18 rows x 191 columns]

# %%
#Vemos la informacion sobre los datos importados. Observamos que el index contiene datos descriptivos
data_covid.info()
data_covid.index.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, continent to male_smokers
# Columns: 191 entries, AFG to ZWE
# dtypes: object(191)
# memory usage: 27.0+ KB
# array(['continent', 'location', 'population', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'cardiovasc_death_rate', 'diabetes_prevalence',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'data',
#        'extreme_poverty', 'female_smokers', 'male_smokers'], dtype=object)

# %%
#reindexamos el dataframe y convertimos los valores del index en columnas
data_covid=data_covid.T
data_covid.columns.values
# Out:
# array(['continent', 'location', 'population', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'cardiovasc_death_rate', 'diabetes_prevalence',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'data',
#        'extreme_poverty', 'female_smokers', 'male_smokers'], dtype=object)

# %%
data_covid
# Out:
#          continent     location   population population_density median_age  \
# AFG           Asia  Afghanistan  3.89283e+07             54.422       18.6
# ALB         Europe      Albania   2.8778e+06            104.871         38
# DZA         Africa      Algeria   4.3851e+07             17.348       29.1
# AND         Europe      Andorra        77265            163.755        NaN
# AGO         Africa       Angola  3.28663e+07              23.89       16.8
# ...            ...          ...          ...                ...        ...
# VNM           Asia      Vietnam  9.73386e+07            308.127       32.6
# OWID_WRL       NaN        World   7.7948e+09             58.045       30.9
# YEM           Asia        Yemen   2.9826e+07             53.508       20.3
# ZMB         Africa       Zambia   1.8384e+07             22.995       17.7
# ZWE         Africa     Zimbabwe  1.48629e+07             42.729       19.6
#
#          aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# AFG              2.581         1.337        1803.99               597.029
# ALB             13.188         8.643        11803.4               304.195
# DZA              6.211         3.857        13913.8               278.364
# AND                NaN           NaN            NaN               109.135
# AGO              2.405         1.362        5819.49               276.045
# ...                ...           ...            ...                   ...
# VNM               7.15         4.718        6171.88               245.465
# OWID_WRL         8.696         5.355        15469.2                233.07
# YEM              2.922         1.583        1479.15               495.003
# ZMB               2.48         1.542        3689.25               234.499
# ZWE              2.822         1.882        1899.78               307.846
#
#          diabetes_prevalence handwashing_facilities  \
# AFG                     9.59                 37.746
# ALB                    10.08                    NaN
# DZA                     6.73                 83.741
# AND                     7.97                    NaN
# AGO                     3.94                 26.664
# ...                      ...                    ...
# VNM                        6                 85.847
# OWID_WRL                8.51                  60.13
# YEM                     5.35                 49.542
# ZMB                     3.94                 13.938
# ZWE                     1.82                 36.791
#
#          hospital_beds_per_thousand life_expectancy human_development_index  \
# AFG                             0.5           64.83                   0.498
# ALB                            2.89           78.57                   0.785
# DZA                             1.9           76.88                   0.754
# AND                             NaN           83.73                   0.858
# AGO                             NaN           61.15                   0.581
# ...                             ...             ...                     ...
# VNM                             2.6            75.4                   0.694
# OWID_WRL                      2.705           72.58                     NaN
# YEM                             0.7           66.12                   0.452
# ZMB                               2           63.89                   0.588
# ZWE                             1.7           61.49                   0.535
#
#                                                        data extreme_poverty  \
# AFG       [{'date': '2020-02-24', 'total_cases': 1.0, 'n...             NaN
# ALB       [{'date': '2020-03-09', 'total_cases': 2.0, 'n...             1.1
# DZA       [{'date': '2020-02-25', 'total_cases': 1.0, 'n...             0.5
# AND       [{'date': '2020-03-02', 'total_cases': 1.0, 'n...             NaN
# AGO       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...             NaN
# ...                                                     ...             ...
# VNM       [{'date': '2020-01-23', 'total_cases': 2.0, 'n...               2
# OWID_WRL  [{'date': '2020-01-22', 'total_cases': 557.0, ...              10
# YEM       [{'date': '2020-04-10', 'total_cases': 1.0, 'n...            18.8
# ZMB       [{'date': '2020-03-18', 'total_cases': 2.0, 'n...            57.5
# ZWE       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...            21.4
#
#          female_smokers male_smokers
# AFG                 NaN          NaN
# ALB                 7.1         51.2
# DZA                 0.7         30.4
# AND                  29         37.8
# AGO                 NaN          NaN
# ...                 ...          ...
# VNM                   1         45.9
# OWID_WRL          6.434       34.635
# YEM                 7.6         29.2
# ZMB                 3.1         24.7
# ZWE                 1.6         30.7
#
# [191 rows x 18 columns]

# %%
#vemos la columna data que incluye informacion adicional no desglosada
data_covid['data']
# Out:
# AFG         [{'date': '2020-02-24', 'total_cases': 1.0, 'n...
# ALB         [{'date': '2020-03-09', 'total_cases': 2.0, 'n...
# DZA         [{'date': '2020-02-25', 'total_cases': 1.0, 'n...
# AND         [{'date': '2020-03-02', 'total_cases': 1.0, 'n...
# AGO         [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
#                                   ...
# VNM         [{'date': '2020-01-23', 'total_cases': 2.0, 'n...
# OWID_WRL    [{'date': '2020-01-22', 'total_cases': 557.0, ...
# YEM         [{'date': '2020-04-10', 'total_cases': 1.0, 'n...
# ZMB         [{'date': '2020-03-18', 'total_cases': 2.0, 'n...
# ZWE         [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
# Name: data, Length: 191, dtype: object

# %%
data_data_covid = data_covid.loc[:, ['data']]
data_data_covid
# Out:
#                                                        data
# AFG       [{'date': '2020-02-24', 'total_cases': 1.0, 'n...
# ALB       [{'date': '2020-03-09', 'total_cases': 2.0, 'n...
# DZA       [{'date': '2020-02-25', 'total_cases': 1.0, 'n...
# AND       [{'date': '2020-03-02', 'total_cases': 1.0, 'n...
# AGO       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
# ...                                                     ...
# VNM       [{'date': '2020-01-23', 'total_cases': 2.0, 'n...
# OWID_WRL  [{'date': '2020-01-22', 'total_cases': 557.0, ...
# YEM       [{'date': '2020-04-10', 'total_cases': 1.0, 'n...
# ZMB       [{'date': '2020-03-18', 'total_cases': 2.0, 'n...
# ZWE       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...
#
# [191 rows x 1 columns]

# %%
df_final = None
for ind in data_data_covid.index.values:
    for i, x in enumerate(data_data_covid['data']):
        if i == 0:
            df_final = pd.DataFrame(x)
        else:
            df_final = pd.concat([df_final, pd.DataFrame(x)], axis=0)
    #print(ind)
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4bb3718f8b08> in <module>
#       5             df_final = pd.DataFrame(x)
#       6         else:
# ----> 7             df_final = pd.concat([df_final, pd.DataFrame(x)], axis=0)
#       8     #print(ind)
#       9 df_final
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     360
#     361             # consolidate
# --> 362             obj._consolidate(inplace=True)
#     363             ndims.add(obj.ndim)
#     364
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _consolidate(self, inplace)
#    5232         inplace = validate_bool_kwarg(inplace, "inplace")
#    5233         if inplace:
# -> 5234             self._consolidate_inplace()
#    5235         else:
#    5236             f = lambda: self._mgr.consolidate()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5214             self._mgr = self._mgr.consolidate()
#    5215
# -> 5216         self._protect_consolidate(f)
#    5217
#    5218     def _consolidate(self, inplace: bool_t = False):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5203         """
#    5204         blocks_before = len(self._mgr.blocks)
# -> 5205         result = f()
#    5206         if len(self._mgr.blocks) != blocks_before:
#    5207             self._clear_item_cache()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in f()
#    5212
#    5213         def f():
# -> 5214             self._mgr = self._mgr.consolidate()
#    5215
#    5216         self._protect_consolidate(f)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     981         bm = type(self)(self.blocks, self.axes)
#     982         bm._is_consolidated = False
# --> 983         bm._consolidate_inplace()
#     984         return bm
#     985
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     986     def _consolidate_inplace(self) -> None:
#     987         if not self.is_consolidated():
# --> 988             self.blocks = tuple(_consolidate(self.blocks))
#     989             self._is_consolidated = True
#     990             self._known_consolidated = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1906     new_blocks = []
#    1907     for (_can_consolidate, dtype), group_blocks in grouper:
# -> 1908         merged_blocks = _merge_blocks(
#    1909             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1910         )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1932
#    1933         argsort = np.argsort(new_mgr_locs)
# -> 1934         new_values = new_values[argsort]
#    1935         new_mgr_locs = new_mgr_locs[argsort]
#    1936
#
# KeyboardInterrupt:

# %%
df_final
# Out:
#            date  total_cases  new_cases  total_cases_per_million  \
# 0    2020-02-24          1.0        1.0                    0.026
# 1    2020-02-25          1.0        0.0                    0.026
# 2    2020-02-26          1.0        0.0                    0.026
# 3    2020-02-27          1.0        0.0                    0.026
# 4    2020-02-28          1.0        0.0                    0.026
# ..          ...          ...        ...                      ...
# 300  2021-01-14      25368.0     1112.0                 1706.797
# 301  2021-01-15      26109.0      741.0                 1756.653
# 302  2021-01-16      26881.0      772.0                 1808.594
# 303  2021-01-17      27203.0      322.0                 1830.259
# 304  2021-01-18      27892.0      689.0                 1876.616
#
#      new_cases_per_million  stringency_index  new_cases_smoothed  \
# 0                    0.026              8.33                 NaN
# 1                    0.000              8.33                 NaN
# 2                    0.000              8.33                 NaN
# 3                    0.000              8.33                 NaN
# 4                    0.000              8.33                 NaN
# ..                     ...               ...                 ...
# 300                 74.817             87.04             956.143
# 301                 49.856             87.04             921.286
# 302                 51.941             87.04             911.714
# 303                 21.665             87.04             818.000
# 304                 46.357               NaN             799.286
#
#      new_deaths_smoothed  new_cases_smoothed_per_million  \
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN
# ..                   ...                             ...
# 300               27.143                          64.331
# 301               28.286                          61.985
# 302               28.571                          61.342
# 303               29.429                          55.036
# 304               35.000                          53.777
#
#      new_deaths_smoothed_per_million  ...  \
# 0                                NaN  ...
# 1                                NaN  ...
# 2                                NaN  ...
# 3                                NaN  ...
# 4                                NaN  ...
# ..                               ...  ...
# 300                            1.826  ...
# 301                            1.903  ...
# 302                            1.922  ...
# 303                            1.980  ...
# 304                            2.355  ...
#
#      new_vaccinations_smoothed_per_million  icu_patients  \
# 0                                      NaN           NaN
# 1                                      NaN           NaN
# 2                                      NaN           NaN
# 3                                      NaN           NaN
# 4                                      NaN           NaN
# ..                                     ...           ...
# 300                                    NaN           NaN
# 301                                    NaN           NaN
# 302                                    NaN           NaN
# 303                                    NaN           NaN
# 304                                    NaN           NaN
#
#      icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                         NaN            NaN                        NaN
# 1                         NaN            NaN                        NaN
# 2                         NaN            NaN                        NaN
# 3                         NaN            NaN                        NaN
# 4                         NaN            NaN                        NaN
# ..                        ...            ...                        ...
# 300                       NaN            NaN                        NaN
# 301                       NaN            NaN                        NaN
# 302                       NaN            NaN                        NaN
# 303                       NaN            NaN                        NaN
# 304                       NaN            NaN                        NaN
#
#      new_vaccinations  weekly_hosp_admissions  \
# 0                 NaN                     NaN
# 1                 NaN                     NaN
# 2                 NaN                     NaN
# 3                 NaN                     NaN
# 4                 NaN                     NaN
# ..                ...                     ...
# 300               NaN                     NaN
# 301               NaN                     NaN
# 302               NaN                     NaN
# 303               NaN                     NaN
# 304               NaN                     NaN
#
#     weekly_hosp_admissions_per_million  weekly_icu_admissions  \
# 0                                  NaN                    NaN
# 1                                  NaN                    NaN
# 2                                  NaN                    NaN
# 3                                  NaN                    NaN
# 4                                  NaN                    NaN
# ..                                 ...                    ...
# 300                                NaN                    NaN
# 301                                NaN                    NaN
# 302                                NaN                    NaN
# 303                                NaN                    NaN
# 304                                NaN                    NaN
#
#      weekly_icu_admissions_per_million
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 300                                NaN
# 301                                NaN
# 302                                NaN
# 303                                NaN
# 304                                NaN
#
# [60542 rows x 37 columns]
