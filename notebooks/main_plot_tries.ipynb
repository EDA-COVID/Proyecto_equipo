# %% [markdown]
# Group A: Anais, Andreea y Mar
#
# Countries assigned:
#     Argentina, Russia, Colombia, Chile and Spain
#
#
# Option C
#
# 1. Document all steps. Structure your code to keep it cleaned using good practices.
#
# DONE: 2. Collect Coronavirus Data. It is mandatory that in each call, it collects the last updated data.
#
# MAR: 3. Determine and explain if the data is cleaned. If not, then clean it.
#
# 4. Create an API that returns a Json with the logic explained for your group. The flask server must be executed running the src/api/server.py file.
# 5. Get the jsons generated from your annexed group and plot it. First, try to connect to the private ip of your     annexed group. If it is not possible because of physical issues, then simply use what they generate copying it. If your annexed group cannot give you the necessary json, then annotate it, use the json of another group.
#
# ANAIS: 6. Show different tendencies for each column in your dataset. Show, vertically, the start date and end date of the alarm state in each plot. If there is no alarm state, then show only the start date.
#
# ANDREEA: 7. Draw the workflow of your program. You can use free tools.
#
# 8. Per country, which are the columns that are more related find the correlation between columns with the           correlation matrix.
#
# DONE: 9. Use a different github repository adding all group participants with write permissions. Use that repository to manage the delivery code and resources. It is mandatory that every student of the group does, at least,five commits/push.
#
#     10. Answer the questions:
#         a. What position do your countries occupe respect to the number of total infected, total deaths and                 total recoveries?
#         b. What can you conclude about your data study?
#         c. Are there outliers or some rare data?
#
#
#
# Our API must offer data to Group B and receive it from Group F, as follows:
#
#     We have to offer a json(df):
#     - Group A: it must return a json with one key “n_c_averages” that represents
#     the mean of the “new_cases” per day of all of your countries.
#
#
#     We should receive a json(df):
#     - Group F: it must return a json with one key “n_t_averages” that represents the
#     mean of the “new_tests” per day of all your countries.
#
# Option B.... to be continued

# %%
#importamos librerias y funciones
import pandas as pd
import seaborn as sns
from utils.folders_tb import jsonlink_df
from utils.mining_data_tb import filter_df, df_covid, remove_outlier, datetime
from utils.visualization_tb import heatmap_df, detect_outliers_df, plot_per_column_distribution

# %%
#Importamos el dataset actualizado
covid = jsonlink_df('https://covid.ourworldindata.org/data/owid-covid-data.json').T
covid
# Out:
#          continent     location   population population_density median_age  \
# AFG           Asia  Afghanistan  3.89283e+07             54.422       18.6
# ALB         Europe      Albania   2.8778e+06            104.871         38
# DZA         Africa      Algeria   4.3851e+07             17.348       29.1
# AND         Europe      Andorra        77265            163.755        NaN
# AGO         Africa       Angola  3.28663e+07              23.89       16.8
# ...            ...          ...          ...                ...        ...
# VNM           Asia      Vietnam  9.73386e+07            308.127       32.6
# OWID_WRL       NaN        World   7.7948e+09             58.045       30.9
# YEM           Asia        Yemen   2.9826e+07             53.508       20.3
# ZMB         Africa       Zambia   1.8384e+07             22.995       17.7
# ZWE         Africa     Zimbabwe  1.48629e+07             42.729       19.6
#
#          aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# AFG              2.581         1.337        1803.99               597.029
# ALB             13.188         8.643        11803.4               304.195
# DZA              6.211         3.857        13913.8               278.364
# AND                NaN           NaN            NaN               109.135
# AGO              2.405         1.362        5819.49               276.045
# ...                ...           ...            ...                   ...
# VNM               7.15         4.718        6171.88               245.465
# OWID_WRL         8.696         5.355        15469.2                233.07
# YEM              2.922         1.583        1479.15               495.003
# ZMB               2.48         1.542        3689.25               234.499
# ZWE              2.822         1.882        1899.78               307.846
#
#          diabetes_prevalence handwashing_facilities  \
# AFG                     9.59                 37.746
# ALB                    10.08                    NaN
# DZA                     6.73                 83.741
# AND                     7.97                    NaN
# AGO                     3.94                 26.664
# ...                      ...                    ...
# VNM                        6                 85.847
# OWID_WRL                8.51                  60.13
# YEM                     5.35                 49.542
# ZMB                     3.94                 13.938
# ZWE                     1.82                 36.791
#
#          hospital_beds_per_thousand life_expectancy human_development_index  \
# AFG                             0.5           64.83                   0.498
# ALB                            2.89           78.57                   0.785
# DZA                             1.9           76.88                   0.754
# AND                             NaN           83.73                   0.858
# AGO                             NaN           61.15                   0.581
# ...                             ...             ...                     ...
# VNM                             2.6            75.4                   0.694
# OWID_WRL                      2.705           72.58                     NaN
# YEM                             0.7           66.12                   0.452
# ZMB                               2           63.89                   0.588
# ZWE                             1.7           61.49                   0.535
#
#                                                        data extreme_poverty  \
# AFG       [{'date': '2020-02-24', 'total_cases': 1.0, 'n...             NaN
# ALB       [{'date': '2020-03-09', 'total_cases': 2.0, 'n...             1.1
# DZA       [{'date': '2020-02-25', 'total_cases': 1.0, 'n...             0.5
# AND       [{'date': '2020-03-02', 'total_cases': 1.0, 'n...             NaN
# AGO       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...             NaN
# ...                                                     ...             ...
# VNM       [{'date': '2020-01-23', 'total_cases': 2.0, 'n...               2
# OWID_WRL  [{'date': '2020-01-22', 'total_cases': 557.0, ...              10
# YEM       [{'date': '2020-04-10', 'total_cases': 1.0, 'n...            18.8
# ZMB       [{'date': '2020-03-18', 'total_cases': 2.0, 'n...            57.5
# ZWE       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...            21.4
#
#          female_smokers male_smokers
# AFG                 NaN          NaN
# ALB                 7.1         51.2
# DZA                 0.7         30.4
# AND                  29         37.8
# AGO                 NaN          NaN
# ...                 ...          ...
# VNM                   1         45.9
# OWID_WRL          6.434       34.635
# YEM                 7.6         29.2
# ZMB                 3.1         24.7
# ZWE                 1.6         30.7
#
# [191 rows x 18 columns]

# %%
#Filtramos nuestros paises
covid=filter_df(covid,'location','Argentina','Russia', 'Colombia', 'Chile', 'Spain')
covid
# Out:
#          continent   location   population population_density median_age  \
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# CHL  South America      Chile  1.91162e+07             24.282       35.4
# COL  South America   Colombia  5.08829e+07             44.223       32.2
# RUS         Europe     Russia  1.45934e+08              8.823       39.6
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
#
#     aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# ARG        11.198         7.441        18933.9               191.032
# CHL        11.087         6.938          22767               127.993
# COL         7.646         4.312        13254.9                124.24
# RUS        14.178         9.393          24766               431.297
# ESP        19.436        13.799        34272.4                99.403
#
#     diabetes_prevalence handwashing_facilities hospital_beds_per_thousand  \
# ARG                 5.5                    NaN                          5
# CHL                8.46                    NaN                       2.11
# COL                7.44                 65.386                       1.71
# RUS                6.18                    NaN                       8.05
# ESP                7.17                    NaN                       2.97
#
#     life_expectancy human_development_index  \
# ARG           76.67                   0.825
# CHL           80.18                   0.843
# COL           77.29                   0.747
# RUS           72.58                   0.816
# ESP           83.56                   0.891
#
#                                                   data extreme_poverty  \
# ARG  [{'date': '2020-01-01', 'total_tests': 4.0, 'n...             0.6
# CHL  [{'date': '2020-02-23', 'total_cases': 2.0, 'n...             1.3
# COL  [{'date': '2020-03-06', 'total_cases': 1.0, 'n...             4.5
# RUS  [{'date': '2020-01-31', 'total_cases': 2.0, 'n...             0.1
# ESP  [{'date': '2020-02-01', 'total_cases': 1.0, 'n...               1
#
#     female_smokers male_smokers
# ARG           16.2         27.7
# CHL           34.2         41.5
# COL            4.7         13.5
# RUS           23.4         58.3
# ESP           27.4         31.4

# %%
#Extraemos la columna "data"
covid=df_covid(covid,val1="data")
covid
# Out:
#           continent   location  population  population_density  median_age  \
# 0     South America  Argentina  45195777.0              16.177        31.9
# 1     South America  Argentina  45195777.0              16.177        31.9
# 2     South America  Argentina  45195777.0              16.177        31.9
# 3     South America  Argentina  45195777.0              16.177        31.9
# 4     South America  Argentina  45195777.0              16.177        31.9
# ...             ...        ...         ...                 ...         ...
# 1741         Europe      Spain  46754783.0              93.105        45.5
# 1742         Europe      Spain  46754783.0              93.105        45.5
# 1743         Europe      Spain  46754783.0              93.105        45.5
# 1744         Europe      Spain  46754783.0              93.105        45.5
# 1745         Europe      Spain  46754783.0              93.105        45.5
#
#       aged_65_older  aged_70_older  gdp_per_capita  cardiovasc_death_rate  \
# 0            11.198          7.441       18933.907                191.032
# 1            11.198          7.441       18933.907                191.032
# 2            11.198          7.441       18933.907                191.032
# 3            11.198          7.441       18933.907                191.032
# 4            11.198          7.441       18933.907                191.032
# ...             ...            ...             ...                    ...
# 1741         19.436         13.799       34272.360                 99.403
# 1742         19.436         13.799       34272.360                 99.403
# 1743         19.436         13.799       34272.360                 99.403
# 1744         19.436         13.799       34272.360                 99.403
# 1745         19.436         13.799       34272.360                 99.403
#
#       diabetes_prevalence  ...  data.new_vaccinations_smoothed_per_million  \
# 0                    5.50  ...                                         NaN
# 1                    5.50  ...                                         NaN
# 2                    5.50  ...                                         NaN
# 3                    5.50  ...                                         NaN
# 4                    5.50  ...                                         NaN
# ...                   ...  ...                                         ...
# 1741                 7.17  ...                                      1500.0
# 1742                 7.17  ...                                      1501.0
# 1743                 7.17  ...                                      1502.0
# 1744                 7.17  ...                                      1503.0
# 1745                 7.17  ...                                      1460.0
#
#       data.new_vaccinations  data.weekly_icu_admissions  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 1741                92764.0                         NaN
# 1742                    NaN                         NaN
# 1743                    NaN                         NaN
# 1744                    NaN                         NaN
# 1745                68155.0                         NaN
#
#       data.weekly_icu_admissions_per_million  data.weekly_hosp_admissions  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 1741                                     NaN                          NaN
# 1742                                     NaN                          NaN
# 1743                                     NaN                          NaN
# 1744                                     NaN                          NaN
# 1745                                     NaN                          NaN
#
#       data.weekly_hosp_admissions_per_million  data.icu_patients  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
# ...                                       ...                ...
# 1741                                      NaN                NaN
# 1742                                      NaN                NaN
# 1743                                      NaN                NaN
# 1744                                      NaN                NaN
# 1745                                      NaN                NaN
#
#      data.icu_patients_per_million  data.hosp_patients  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# ...                            ...                 ...
# 1741                           NaN                 NaN
# 1742                           NaN                 NaN
# 1743                           NaN                 NaN
# 1744                           NaN                 NaN
# 1745                           NaN                 NaN
#
#       data.hosp_patients_per_million
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1741                             NaN
# 1742                             NaN
# 1743                             NaN
# 1744                             NaN
# 1745                             NaN
#
# [1746 rows x 54 columns]

# %%
#Cambiamos la columna date a tipo datetime
covid= datetime(dt=covid, val1="data.date")
covid
# Out:
#           continent   location  population  population_density  median_age  \
# 0     South America  Argentina  45195777.0              16.177        31.9
# 1     South America  Argentina  45195777.0              16.177        31.9
# 2     South America  Argentina  45195777.0              16.177        31.9
# 3     South America  Argentina  45195777.0              16.177        31.9
# 4     South America  Argentina  45195777.0              16.177        31.9
# ...             ...        ...         ...                 ...         ...
# 1741         Europe      Spain  46754783.0              93.105        45.5
# 1742         Europe      Spain  46754783.0              93.105        45.5
# 1743         Europe      Spain  46754783.0              93.105        45.5
# 1744         Europe      Spain  46754783.0              93.105        45.5
# 1745         Europe      Spain  46754783.0              93.105        45.5
#
#       aged_65_older  aged_70_older  gdp_per_capita  cardiovasc_death_rate  \
# 0            11.198          7.441       18933.907                191.032
# 1            11.198          7.441       18933.907                191.032
# 2            11.198          7.441       18933.907                191.032
# 3            11.198          7.441       18933.907                191.032
# 4            11.198          7.441       18933.907                191.032
# ...             ...            ...             ...                    ...
# 1741         19.436         13.799       34272.360                 99.403
# 1742         19.436         13.799       34272.360                 99.403
# 1743         19.436         13.799       34272.360                 99.403
# 1744         19.436         13.799       34272.360                 99.403
# 1745         19.436         13.799       34272.360                 99.403
#
#       diabetes_prevalence  ...  data.new_vaccinations_smoothed_per_million  \
# 0                    5.50  ...                                         NaN
# 1                    5.50  ...                                         NaN
# 2                    5.50  ...                                         NaN
# 3                    5.50  ...                                         NaN
# 4                    5.50  ...                                         NaN
# ...                   ...  ...                                         ...
# 1741                 7.17  ...                                      1500.0
# 1742                 7.17  ...                                      1501.0
# 1743                 7.17  ...                                      1502.0
# 1744                 7.17  ...                                      1503.0
# 1745                 7.17  ...                                      1460.0
#
#       data.new_vaccinations  data.weekly_icu_admissions  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 1741                92764.0                         NaN
# 1742                    NaN                         NaN
# 1743                    NaN                         NaN
# 1744                    NaN                         NaN
# 1745                68155.0                         NaN
#
#       data.weekly_icu_admissions_per_million  data.weekly_hosp_admissions  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 1741                                     NaN                          NaN
# 1742                                     NaN                          NaN
# 1743                                     NaN                          NaN
# 1744                                     NaN                          NaN
# 1745                                     NaN                          NaN
#
#       data.weekly_hosp_admissions_per_million  data.icu_patients  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
# ...                                       ...                ...
# 1741                                      NaN                NaN
# 1742                                      NaN                NaN
# 1743                                      NaN                NaN
# 1744                                      NaN                NaN
# 1745                                      NaN                NaN
#
#      data.icu_patients_per_million  data.hosp_patients  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# ...                            ...                 ...
# 1741                           NaN                 NaN
# 1742                           NaN                 NaN
# 1743                           NaN                 NaN
# 1744                           NaN                 NaN
# 1745                           NaN                 NaN
#
#       data.hosp_patients_per_million
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1741                             NaN
# 1742                             NaN
# 1743                             NaN
# 1744                             NaN
# 1745                             NaN
#
# [1746 rows x 54 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   continent                                   1746 non-null   object
#  1   location                                    1746 non-null   object
#  2   population                                  1746 non-null   float64
#  3   population_density                          1746 non-null   float64
#  4   median_age                                  1746 non-null   float64
#  5   aged_65_older                               1746 non-null   float64
#  6   aged_70_older                               1746 non-null   float64
#  7   gdp_per_capita                              1746 non-null   float64
#  8   cardiovasc_death_rate                       1746 non-null   float64
#  9   diabetes_prevalence                         1746 non-null   float64
#  10  handwashing_facilities                      320 non-null    float64
#  11  hospital_beds_per_thousand                  1746 non-null   float64
#  12  life_expectancy                             1746 non-null   float64
#  13  human_development_index                     1746 non-null   float64
#  14  extreme_poverty                             1746 non-null   float64
#  15  female_smokers                              1746 non-null   float64
#  16  male_smokers                                1746 non-null   float64
#  17  data.date                                   1746 non-null   datetime64[ns]
#  18  data.total_tests                            1209 non-null   float64
#  19  data.new_tests                              1157 non-null   float64
#  20  data.total_tests_per_thousand               1209 non-null   float64
#  21  data.new_tests_per_thousand                 1157 non-null   float64
#  22  data.tests_units                            1483 non-null   object
#  23  data.stringency_index                       1739 non-null   float64
#  24  data.new_tests_smoothed                     1448 non-null   float64
#  25  data.new_tests_smoothed_per_thousand        1448 non-null   float64
#  26  data.total_cases                            1684 non-null   float64
#  27  data.new_cases                              1684 non-null   float64
#  28  data.total_cases_per_million                1684 non-null   float64
#  29  data.new_cases_per_million                  1684 non-null   float64
#  30  data.new_cases_smoothed                     1659 non-null   float64
#  31  data.total_deaths                           1556 non-null   float64
#  32  data.new_deaths                             1556 non-null   float64
#  33  data.new_deaths_smoothed                    1659 non-null   float64
#  34  data.new_cases_smoothed_per_million         1659 non-null   float64
#  35  data.total_deaths_per_million               1556 non-null   float64
#  36  data.new_deaths_per_million                 1556 non-null   float64
#  37  data.new_deaths_smoothed_per_million        1659 non-null   float64
#  38  data.positive_rate                          1382 non-null   float64
#  39  data.tests_per_case                         1382 non-null   float64
#  40  data.reproduction_rate                      1498 non-null   float64
#  41  data.total_vaccinations                     35 non-null     float64
#  42  data.total_vaccinations_per_hundred         35 non-null     float64
#  43  data.new_vaccinations_smoothed              87 non-null     float64
#  44  data.new_vaccinations_smoothed_per_million  87 non-null     float64
#  45  data.new_vaccinations                       18 non-null     float64
#  46  data.weekly_icu_admissions                  50 non-null     float64
#  47  data.weekly_icu_admissions_per_million      50 non-null     float64
#  48  data.weekly_hosp_admissions                 50 non-null     float64
#  49  data.weekly_hosp_admissions_per_million     50 non-null     float64
#  50  data.icu_patients                           97 non-null     float64
#  51  data.icu_patients_per_million               97 non-null     float64
#  52  data.hosp_patients                          97 non-null     float64
#  53  data.hosp_patients_per_million              97 non-null     float64
# dtypes: datetime64[ns](1), float64(50), object(3)
# memory usage: 736.7+ KB

# %%
#eliminamos columnas con muchos Nan
covid= covid.drop(["continent", "extreme_poverty", "human_development_index","hospital_beds_per_thousand", "diabetes_prevalence","female_smokers","cardiovasc_death_rate", "aged_70_older", "aged_65_older", "median_age", "population_density", "gdp_per_capita", "male_smokers","data.new_vaccinations","data.total_vaccinations_per_hundred","data.total_vaccinations","data.weekly_hosp_admissions_per_million","data.weekly_hosp_admissions","data.weekly_icu_admissions_per_million","data.weekly_icu_admissions","data.new_vaccinations_smoothed","data.new_vaccinations_smoothed_per_million","data.hosp_patients","data.hosp_patients_per_million","data.icu_patients","data.icu_patients_per_million","handwashing_facilities"],axis=1)
covid
# Out:
#        location  population  life_expectancy  data.date  data.total_tests  \
# 0     Argentina  45195777.0            76.67 2020-01-01               4.0
# 1     Argentina  45195777.0            76.67 2020-01-02              14.0
# 2     Argentina  45195777.0            76.67 2020-01-03              19.0
# 3     Argentina  45195777.0            76.67 2020-01-04              31.0
# 4     Argentina  45195777.0            76.67 2020-01-05              41.0
# ...         ...         ...              ...        ...               ...
# 1741      Spain  46754783.0            83.56 2021-01-15               NaN
# 1742      Spain  46754783.0            83.56 2021-01-16               NaN
# 1743      Spain  46754783.0            83.56 2021-01-17               NaN
# 1744      Spain  46754783.0            83.56 2021-01-18               NaN
# 1745      Spain  46754783.0            83.56 2021-01-19               NaN
#
#       data.new_tests  data.total_tests_per_thousand  \
# 0                4.0                          0.000
# 1               10.0                          0.000
# 2                5.0                          0.000
# 3               12.0                          0.001
# 4               10.0                          0.001
# ...              ...                            ...
# 1741             NaN                            NaN
# 1742             NaN                            NaN
# 1743             NaN                            NaN
# 1744             NaN                            NaN
# 1745             NaN                            NaN
#
#       data.new_tests_per_thousand data.tests_units  data.stringency_index  \
# 0                             0.0    people tested                    0.0
# 1                             0.0    people tested                    0.0
# 2                             0.0    people tested                    0.0
# 3                             0.0    people tested                    0.0
# 4                             0.0    people tested                    0.0
# ...                           ...              ...                    ...
# 1741                          NaN              NaN                   71.3
# 1742                          NaN              NaN                   71.3
# 1743                          NaN              NaN                   71.3
# 1744                          NaN              NaN                    NaN
# 1745                          NaN              NaN                    NaN
#
#       ...  data.total_deaths  data.new_deaths  data.new_deaths_smoothed  \
# 0     ...                NaN              NaN                       NaN
# 1     ...                NaN              NaN                       NaN
# 2     ...                NaN              NaN                       NaN
# 3     ...                NaN              NaN                       NaN
# 4     ...                NaN              NaN                       NaN
# ...   ...                ...              ...                       ...
# 1741  ...            53314.0            235.0                   205.714
# 1742  ...            53314.0              0.0                   205.714
# 1743  ...            53314.0              0.0                   205.714
# 1744  ...            53769.0            455.0                   213.429
# 1745  ...            54173.0            404.0                   212.857
#
#       data.new_cases_smoothed_per_million  data.total_deaths_per_million  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
# ...                                   ...                            ...
# 1741                              616.603                       1140.290
# 1742                              616.603                       1140.290
# 1743                              616.603                       1140.290
# 1744                              686.466                       1150.021
# 1745                              713.516                       1158.662
#
#       data.new_deaths_per_million  data.new_deaths_smoothed_per_million  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 1741                        5.026                                 4.400
# 1742                        0.000                                 4.400
# 1743                        0.000                                 4.400
# 1744                        9.732                                 4.565
# 1745                        8.641                                 4.553
#
#       data.positive_rate  data.tests_per_case  data.reproduction_rate
# 0                    NaN                  NaN                     NaN
# 1                    NaN                  NaN                     NaN
# 2                    NaN                  NaN                     NaN
# 3                    NaN                  NaN                     NaN
# 4                    NaN                  NaN                     NaN
# ...                  ...                  ...                     ...
# 1741                 NaN                  NaN                     NaN
# 1742                 NaN                  NaN                     NaN
# 1743                 NaN                  NaN                     NaN
# 1744                 NaN                  NaN                     NaN
# 1745                 NaN                  NaN                     NaN
#
# [1746 rows x 27 columns]

# %%
covid.isna().sum().sort_values(ascending=False)
# Out:
# data.new_tests_per_thousand             589
# data.new_tests                          589
# data.total_tests_per_thousand           537
# data.total_tests                        537
# data.positive_rate                      364
# data.tests_per_case                     364
# data.new_tests_smoothed                 298
# data.new_tests_smoothed_per_thousand    298
# data.tests_units                        263
# data.reproduction_rate                  248
# data.new_deaths                         190
# data.total_deaths_per_million           190
# data.new_deaths_per_million             190
# data.total_deaths                       190
# data.new_cases_smoothed                  87
# data.new_deaths_smoothed                 87
# data.new_cases_smoothed_per_million      87
# data.new_deaths_smoothed_per_million     87
# data.new_cases                           62
# data.total_cases                         62
# data.total_cases_per_million             62
# data.new_cases_per_million               62
# data.stringency_index                     7
# data.date                                 0
# life_expectancy                           0
# population                                0
# location                                  0
# dtype: int64

# %%
#matrix de correlación entre nuestras columnas
heatmap_df(df=covid, file_name='first_plot')

# %%
plot_per_column_distribution(covid,37,3,'hist one')

# %%
covid
# Out:
#        location  population  life_expectancy  data.date  data.total_tests  \
# 0     Argentina  45195777.0            76.67 2020-01-01               4.0
# 1     Argentina  45195777.0            76.67 2020-01-02              14.0
# 2     Argentina  45195777.0            76.67 2020-01-03              19.0
# 3     Argentina  45195777.0            76.67 2020-01-04              31.0
# 4     Argentina  45195777.0            76.67 2020-01-05              41.0
# ...         ...         ...              ...        ...               ...
# 1741      Spain  46754783.0            83.56 2021-01-15               NaN
# 1742      Spain  46754783.0            83.56 2021-01-16               NaN
# 1743      Spain  46754783.0            83.56 2021-01-17               NaN
# 1744      Spain  46754783.0            83.56 2021-01-18               NaN
# 1745      Spain  46754783.0            83.56 2021-01-19               NaN
#
#       data.new_tests  data.total_tests_per_thousand  \
# 0                4.0                          0.000
# 1               10.0                          0.000
# 2                5.0                          0.000
# 3               12.0                          0.001
# 4               10.0                          0.001
# ...              ...                            ...
# 1741             NaN                            NaN
# 1742             NaN                            NaN
# 1743             NaN                            NaN
# 1744             NaN                            NaN
# 1745             NaN                            NaN
#
#       data.new_tests_per_thousand data.tests_units  data.stringency_index  \
# 0                             0.0    people tested                    0.0
# 1                             0.0    people tested                    0.0
# 2                             0.0    people tested                    0.0
# 3                             0.0    people tested                    0.0
# 4                             0.0    people tested                    0.0
# ...                           ...              ...                    ...
# 1741                          NaN              NaN                   71.3
# 1742                          NaN              NaN                   71.3
# 1743                          NaN              NaN                   71.3
# 1744                          NaN              NaN                    NaN
# 1745                          NaN              NaN                    NaN
#
#       ...  data.total_deaths  data.new_deaths  data.new_deaths_smoothed  \
# 0     ...                NaN              NaN                       NaN
# 1     ...                NaN              NaN                       NaN
# 2     ...                NaN              NaN                       NaN
# 3     ...                NaN              NaN                       NaN
# 4     ...                NaN              NaN                       NaN
# ...   ...                ...              ...                       ...
# 1741  ...            53314.0            235.0                   205.714
# 1742  ...            53314.0              0.0                   205.714
# 1743  ...            53314.0              0.0                   205.714
# 1744  ...            53769.0            455.0                   213.429
# 1745  ...            54173.0            404.0                   212.857
#
#       data.new_cases_smoothed_per_million  data.total_deaths_per_million  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
# ...                                   ...                            ...
# 1741                              616.603                       1140.290
# 1742                              616.603                       1140.290
# 1743                              616.603                       1140.290
# 1744                              686.466                       1150.021
# 1745                              713.516                       1158.662
#
#       data.new_deaths_per_million  data.new_deaths_smoothed_per_million  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 1741                        5.026                                 4.400
# 1742                        0.000                                 4.400
# 1743                        0.000                                 4.400
# 1744                        9.732                                 4.565
# 1745                        8.641                                 4.553
#
#       data.positive_rate  data.tests_per_case  data.reproduction_rate
# 0                    NaN                  NaN                     NaN
# 1                    NaN                  NaN                     NaN
# 2                    NaN                  NaN                     NaN
# 3                    NaN                  NaN                     NaN
# 4                    NaN                  NaN                     NaN
# ...                  ...                  ...                     ...
# 1741                 NaN                  NaN                     NaN
# 1742                 NaN                  NaN                     NaN
# 1743                 NaN                  NaN                     NaN
# 1744                 NaN                  NaN                     NaN
# 1745                 NaN                  NaN                     NaN
#
# [1746 rows x 27 columns]

# %%
covid.set_index('data.date', inplace=True)
covid
# Out:
#              location  population  life_expectancy  data.total_tests  \
# data.date
# 2020-01-01  Argentina  45195777.0            76.67               4.0
# 2020-01-02  Argentina  45195777.0            76.67              14.0
# 2020-01-03  Argentina  45195777.0            76.67              19.0
# 2020-01-04  Argentina  45195777.0            76.67              31.0
# 2020-01-05  Argentina  45195777.0            76.67              41.0
# ...               ...         ...              ...               ...
# 2021-01-15      Spain  46754783.0            83.56               NaN
# 2021-01-16      Spain  46754783.0            83.56               NaN
# 2021-01-17      Spain  46754783.0            83.56               NaN
# 2021-01-18      Spain  46754783.0            83.56               NaN
# 2021-01-19      Spain  46754783.0            83.56               NaN
#
#             data.new_tests  data.total_tests_per_thousand  \
# data.date
# 2020-01-01             4.0                          0.000
# 2020-01-02            10.0                          0.000
# 2020-01-03             5.0                          0.000
# 2020-01-04            12.0                          0.001
# 2020-01-05            10.0                          0.001
# ...                    ...                            ...
# 2021-01-15             NaN                            NaN
# 2021-01-16             NaN                            NaN
# 2021-01-17             NaN                            NaN
# 2021-01-18             NaN                            NaN
# 2021-01-19             NaN                            NaN
#
#             data.new_tests_per_thousand data.tests_units  \
# data.date
# 2020-01-01                          0.0    people tested
# 2020-01-02                          0.0    people tested
# 2020-01-03                          0.0    people tested
# 2020-01-04                          0.0    people tested
# 2020-01-05                          0.0    people tested
# ...                                 ...              ...
# 2021-01-15                          NaN              NaN
# 2021-01-16                          NaN              NaN
# 2021-01-17                          NaN              NaN
# 2021-01-18                          NaN              NaN
# 2021-01-19                          NaN              NaN
#
#             data.stringency_index  data.new_tests_smoothed  ...  \
# data.date                                                   ...
# 2020-01-01                    0.0                      NaN  ...
# 2020-01-02                    0.0                      NaN  ...
# 2020-01-03                    0.0                      NaN  ...
# 2020-01-04                    0.0                      NaN  ...
# 2020-01-05                    0.0                      NaN  ...
# ...                           ...                      ...  ...
# 2021-01-15                   71.3                      NaN  ...
# 2021-01-16                   71.3                      NaN  ...
# 2021-01-17                   71.3                      NaN  ...
# 2021-01-18                    NaN                      NaN  ...
# 2021-01-19                    NaN                      NaN  ...
#
#             data.total_deaths  data.new_deaths  data.new_deaths_smoothed  \
# data.date
# 2020-01-01                NaN              NaN                       NaN
# 2020-01-02                NaN              NaN                       NaN
# 2020-01-03                NaN              NaN                       NaN
# 2020-01-04                NaN              NaN                       NaN
# 2020-01-05                NaN              NaN                       NaN
# ...                       ...              ...                       ...
# 2021-01-15            53314.0            235.0                   205.714
# 2021-01-16            53314.0              0.0                   205.714
# 2021-01-17            53314.0              0.0                   205.714
# 2021-01-18            53769.0            455.0                   213.429
# 2021-01-19            54173.0            404.0                   212.857
#
#             data.new_cases_smoothed_per_million  \
# data.date
# 2020-01-01                                  NaN
# 2020-01-02                                  NaN
# 2020-01-03                                  NaN
# 2020-01-04                                  NaN
# 2020-01-05                                  NaN
# ...                                         ...
# 2021-01-15                              616.603
# 2021-01-16                              616.603
# 2021-01-17                              616.603
# 2021-01-18                              686.466
# 2021-01-19                              713.516
#
#             data.total_deaths_per_million  data.new_deaths_per_million  \
# data.date
# 2020-01-01                            NaN                          NaN
# 2020-01-02                            NaN                          NaN
# 2020-01-03                            NaN                          NaN
# 2020-01-04                            NaN                          NaN
# 2020-01-05                            NaN                          NaN
# ...                                   ...                          ...
# 2021-01-15                       1140.290                        5.026
# 2021-01-16                       1140.290                        0.000
# 2021-01-17                       1140.290                        0.000
# 2021-01-18                       1150.021                        9.732
# 2021-01-19                       1158.662                        8.641
#
#             data.new_deaths_smoothed_per_million  data.positive_rate  \
# data.date
# 2020-01-01                                   NaN                 NaN
# 2020-01-02                                   NaN                 NaN
# 2020-01-03                                   NaN                 NaN
# 2020-01-04                                   NaN                 NaN
# 2020-01-05                                   NaN                 NaN
# ...                                          ...                 ...
# 2021-01-15                                 4.400                 NaN
# 2021-01-16                                 4.400                 NaN
# 2021-01-17                                 4.400                 NaN
# 2021-01-18                                 4.565                 NaN
# 2021-01-19                                 4.553                 NaN
#
#             data.tests_per_case  data.reproduction_rate
# data.date
# 2020-01-01                  NaN                     NaN
# 2020-01-02                  NaN                     NaN
# 2020-01-03                  NaN                     NaN
# 2020-01-04                  NaN                     NaN
# 2020-01-05                  NaN                     NaN
# ...                         ...                     ...
# 2021-01-15                  NaN                     NaN
# 2021-01-16                  NaN                     NaN
# 2021-01-17                  NaN                     NaN
# 2021-01-18                  NaN                     NaN
# 2021-01-19                  NaN                     NaN
#
# [1746 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

def plot_clean_columns(df_name, df_column):

    created_df = df_name.loc[:, ['location', df_column]]
    created_df = created_df.dropna()
    created_df = created_df.loc[created_df[df_column]!=0.0]
    print(created_df.nunique())
    print('------')

    b = created_df['location'].value_counts()
    print(b)
    print('------')
    b.plot(kind='pie', autopct = "%1.0f%%", colors=['pink', 'lightblue','violet', 'lightgreen', 'gold'])
    plt.xlabel('total data')
    plt.ylabel('')
    print('------')


    for f in set(created_df['location']):
        created_df[created_df['location']==f].plot(y=df_column, title=f, legend=False, xlabel='', color='lightgreen', xticks=['2020-03', '2020-07', '2021-01'])
        if f == 'Spain':
            plt.axvline('2020-03-14')
            plt.axvline('2020-06-21', color='lightblue')
            plt.axvline('2020-10-25')
        if f == 'Colombia':
            plt.axvline('2020-03-12')
            plt.axvline('2020-08-31', color='lightblue')
        if f == 'Chile':
            plt.axvline('2020-03-18')

# %%
plot_clean_columns(df_name=covid, df_column='data.stringency_index')
# Out:
# location                  5
# data.stringency_index    68
# dtype: int64
# ------
# Argentina    362
# Russia       355
# Spain        352
# Colombia     318
# Chile        310
# Name: location, dtype: int64
# ------
# ------

# %%
import matplotlib.pyplot as plt

def plot_clean_columns(df_name, df_column):

    created_df = df_name.loc[:, ['location', df_column]]
    created_df = created_df.dropna()
    created_df = created_df.loc[created_df[df_column]!=0.0]
    print(created_df.nunique())
    print('------')

    b = created_df['location'].value_counts()
    print(b)
    print('------')
    b.plot(kind='pie', autopct = "%1.0f%%", colors=['pink', 'lightblue','violet', 'lightgreen', 'gold'])
    plt.xlabel('total data')
    plt.ylabel('')
    print('------')


    for f in set(created_df['location']):
        created_df[created_df['location']==f].plot(y=df_column, title=f, legend=False, xlabel='', color='lightgreen', ylabel=df_column, xticks=['2020-03', '2020-07', '2021-01'])
        if f == 'Spain':
            plt.axvline('2020-03-14')
            plt.axvline('2020-06-21', color='lightblue')
            plt.axvline('2020-10-25')
        if f == 'Colombia':
            plt.axvline('2020-03-12')
            plt.axvline('2020-08-31', color='lightblue')
        if f == 'Chile':
            plt.axvline('2020-03-18')

# %%
plot_clean_columns(df_name=covid, df_column='data.stringency_index')
# Out:
# location                  5
# data.stringency_index    68
# dtype: int64
# ------
# Argentina    362
# Russia       355
# Spain        352
# Colombia     318
# Chile        310
# Name: location, dtype: int64
# ------
# ------

# %%
import matplotlib.pyplot as plt

def plot_clean_columns(df_name, df_column, y_label):

    created_df = df_name.loc[:, ['location', df_column]]
    created_df = created_df.dropna()
    created_df = created_df.loc[created_df[df_column]!=0.0]
    print(created_df.nunique())
    print('------')

    b = created_df['location'].value_counts()
    print(b)
    print('------')
    b.plot(kind='pie', autopct = "%1.0f%%", colors=['pink', 'lightblue','violet', 'lightgreen', 'gold'])
    plt.xlabel('total data')
    plt.ylabel('')
    print('------')

    created_df.index = created_df.index.astype(str)

    for f in set(created_df['location']):
        created_df[created_df['location']==f].plot(y=df_column, title=f, legend=False, xlabel='', color='lightgreen', ylabel=y_label)
        plt.xticks(rotation=45)
        if f == 'Spain':
            plt.axvline('2020-03-14')
            plt.axvline('2020-06-21', color='lightblue')
            plt.axvline('2020-10-25')
        if f == 'Colombia':
            plt.axvline('2020-03-12')
            plt.axvline('2020-08-31', color='lightblue')
        if f == 'Chile':
            plt.axvline('2020-03-18')

# %%
plot_clean_columns(df_name=covid, df_column='data.stringency_index', y_label='stringency index')
# Out:
# location                  5
# data.stringency_index    68
# dtype: int64
# ------
# Argentina    362
# Russia       355
# Spain        352
# Colombia     318
# Chile        310
# Name: location, dtype: int64
# ------
# ------

# %%
import matplotlib.pyplot as plt

def plot_clean_columns(df_name, df_column, y_label):

    created_df = df_name.loc[:, ['location', df_column]]
    created_df = created_df.dropna()
    created_df = created_df.loc[created_df[df_column]!=0.0]
    print(created_df.nunique())
    print('------')

    b = created_df['location'].value_counts()
    print(b)
    print('------')
    b.plot(kind='pie', autopct = "%1.0f%%", colors=['pink', 'lightblue','violet', 'lightgreen', 'gold'])
    plt.xlabel('total data')
    plt.ylabel('')
    print('------')

    for f in set(created_df['location']):
        ax = created_df[created_df['location']==f].plot(y=df_column, title=f, legend=False, xlabel='', color='lightgreen', ylabel=y_label)
        ax.set_xlim(pd.Timestamp('2020-02-01'), pd.Timestamp('2021-02-01'))
        plt.xticks(rotation=45)
        if f == 'Spain':
            plt.axvline('2020-03-14')
            plt.axvline('2020-06-21', color='lightblue')
            plt.axvline('2020-10-25')
        if f == 'Colombia':
            plt.axvline('2020-03-12')
            plt.axvline('2020-08-31', color='lightblue')
        if f == 'Chile':
            plt.axvline('2020-03-18')

# %%
plot_clean_columns(df_name=covid, df_column='data.stringency_index', y_label='stringency index')
# Out:
# location                  5
# data.stringency_index    68
# dtype: int64
# ------
# Argentina    362
# Russia       355
# Spain        352
# Colombia     318
# Chile        310
# Name: location, dtype: int64
# ------
# ------

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def plot_clean_columns(df_name, df_column, y_label):

    created_df = df_name.loc[:, ['location', df_column]]
    created_df = created_df.dropna()
    created_df = created_df.loc[created_df[df_column]!=0.0]
    print(created_df.nunique())
    print('------')

    b = created_df['location'].value_counts()
    print(b)
    print('------')
    b.plot(kind='pie', autopct = "%1.0f%%", colors=['pink', 'lightblue','violet', 'lightgreen', 'gold'])
    plt.xlabel('total data')
    plt.ylabel('')
    print('------')

    for f in set(created_df['location']):
        ax = created_df[created_df['location']==f].plot(y=df_column, title=f, legend=False, xlabel='', color='lightgreen', ylabel=y_label)
        ax.set_xlim(pd.Timestamp('2020-02-01'), pd.Timestamp('2021-02-01'))
        ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
        plt.gcf().autofmt_xdate()
        if f == 'Spain':
            plt.axvline('2020-03-14')
            plt.axvline('2020-06-21', color='lightblue')
            plt.axvline('2020-10-25')
        if f == 'Colombia':
            plt.axvline('2020-03-12')
            plt.axvline('2020-08-31', color='lightblue')
        if f == 'Chile':
            plt.axvline('2020-03-18')

# %%
plot_clean_columns(df_name=covid, df_column='data.stringency_index', y_label='stringency index')
# Out:
# location                  5
# data.stringency_index    68
# dtype: int64
# ------
# Argentina    362
# Russia       355
# Spain        352
# Colombia     318
# Chile        310
# Name: location, dtype: int64
# ------
# ------
