# %%
import pandas as pd
from utils.folders_tb import jsonlink_df
from utils.mining_data_tb import extract_dict_values,filter_df

# %%
covid = jsonlink_df('https://covid.ourworldindata.org/data/owid-covid-data.json').T
covid
# Out:
#          continent     location   population population_density median_age  \
# AFG           Asia  Afghanistan  3.89283e+07             54.422       18.6
# ALB         Europe      Albania   2.8778e+06            104.871         38
# DZA         Africa      Algeria   4.3851e+07             17.348       29.1
# AND         Europe      Andorra        77265            163.755        NaN
# AGO         Africa       Angola  3.28663e+07              23.89       16.8
# ...            ...          ...          ...                ...        ...
# VNM           Asia      Vietnam  9.73386e+07            308.127       32.6
# OWID_WRL       NaN        World   7.7948e+09             58.045       30.9
# YEM           Asia        Yemen   2.9826e+07             53.508       20.3
# ZMB         Africa       Zambia   1.8384e+07             22.995       17.7
# ZWE         Africa     Zimbabwe  1.48629e+07             42.729       19.6
#
#          aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# AFG              2.581         1.337        1803.99               597.029
# ALB             13.188         8.643        11803.4               304.195
# DZA              6.211         3.857        13913.8               278.364
# AND                NaN           NaN            NaN               109.135
# AGO              2.405         1.362        5819.49               276.045
# ...                ...           ...            ...                   ...
# VNM               7.15         4.718        6171.88               245.465
# OWID_WRL         8.696         5.355        15469.2                233.07
# YEM              2.922         1.583        1479.15               495.003
# ZMB               2.48         1.542        3689.25               234.499
# ZWE              2.822         1.882        1899.78               307.846
#
#          diabetes_prevalence handwashing_facilities  \
# AFG                     9.59                 37.746
# ALB                    10.08                    NaN
# DZA                     6.73                 83.741
# AND                     7.97                    NaN
# AGO                     3.94                 26.664
# ...                      ...                    ...
# VNM                        6                 85.847
# OWID_WRL                8.51                  60.13
# YEM                     5.35                 49.542
# ZMB                     3.94                 13.938
# ZWE                     1.82                 36.791
#
#          hospital_beds_per_thousand life_expectancy human_development_index  \
# AFG                             0.5           64.83                   0.498
# ALB                            2.89           78.57                   0.785
# DZA                             1.9           76.88                   0.754
# AND                             NaN           83.73                   0.858
# AGO                             NaN           61.15                   0.581
# ...                             ...             ...                     ...
# VNM                             2.6            75.4                   0.694
# OWID_WRL                      2.705           72.58                     NaN
# YEM                             0.7           66.12                   0.452
# ZMB                               2           63.89                   0.588
# ZWE                             1.7           61.49                   0.535
#
#                                                        data extreme_poverty  \
# AFG       [{'date': '2020-02-24', 'total_cases': 1.0, 'n...             NaN
# ALB       [{'date': '2020-03-09', 'total_cases': 2.0, 'n...             1.1
# DZA       [{'date': '2020-02-25', 'total_cases': 1.0, 'n...             0.5
# AND       [{'date': '2020-03-02', 'total_cases': 1.0, 'n...             NaN
# AGO       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...             NaN
# ...                                                     ...             ...
# VNM       [{'date': '2020-01-23', 'total_cases': 2.0, 'n...               2
# OWID_WRL  [{'date': '2020-01-22', 'total_cases': 557.0, ...              10
# YEM       [{'date': '2020-04-10', 'total_cases': 1.0, 'n...            18.8
# ZMB       [{'date': '2020-03-18', 'total_cases': 2.0, 'n...            57.5
# ZWE       [{'date': '2020-03-20', 'total_cases': 1.0, 'n...            21.4
#
#          female_smokers male_smokers
# AFG                 NaN          NaN
# ALB                 7.1         51.2
# DZA                 0.7         30.4
# AND                  29         37.8
# AGO                 NaN          NaN
# ...                 ...          ...
# VNM                   1         45.9
# OWID_WRL          6.434       34.635
# YEM                 7.6         29.2
# ZMB                 3.1         24.7
# ZWE                 1.6         30.7
#
# [191 rows x 18 columns]

# %%
covid=filter_df(covid,'location','Argentina','Russia', 'Colombia', 'Chile', 'Spain')
covid
# Out:
#          continent   location   population population_density median_age  \
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# CHL  South America      Chile  1.91162e+07             24.282       35.4
# COL  South America   Colombia  5.08829e+07             44.223       32.2
# RUS         Europe     Russia  1.45934e+08              8.823       39.6
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
#
#     aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# ARG        11.198         7.441        18933.9               191.032
# CHL        11.087         6.938          22767               127.993
# COL         7.646         4.312        13254.9                124.24
# RUS        14.178         9.393          24766               431.297
# ESP        19.436        13.799        34272.4                99.403
#
#     diabetes_prevalence handwashing_facilities hospital_beds_per_thousand  \
# ARG                 5.5                    NaN                          5
# CHL                8.46                    NaN                       2.11
# COL                7.44                 65.386                       1.71
# RUS                6.18                    NaN                       8.05
# ESP                7.17                    NaN                       2.97
#
#     life_expectancy human_development_index  \
# ARG           76.67                   0.825
# CHL           80.18                   0.843
# COL           77.29                   0.747
# RUS           72.58                   0.816
# ESP           83.56                   0.891
#
#                                                   data extreme_poverty  \
# ARG  [{'date': '2020-01-01', 'total_tests': 4.0, 'n...             0.6
# CHL  [{'date': '2020-02-23', 'total_cases': 2.0, 'n...             1.3
# COL  [{'date': '2020-03-06', 'total_cases': 1.0, 'n...             4.5
# RUS  [{'date': '2020-01-31', 'total_cases': 2.0, 'n...             0.1
# ESP  [{'date': '2020-02-01', 'total_cases': 1.0, 'n...               1
#
#     female_smokers male_smokers
# ARG           16.2         27.7
# CHL           34.2         41.5
# COL            4.7         13.5
# RUS           23.4         58.3
# ESP           27.4         31.4

# %%
first = covid.explode("data")
first
# Out:
#          continent   location   population population_density median_age  \
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# ARG  South America  Argentina  4.51958e+07             16.177       31.9
# ..             ...        ...          ...                ...        ...
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
# ESP         Europe      Spain  4.67548e+07             93.105       45.5
#
#     aged_65_older aged_70_older gdp_per_capita cardiovasc_death_rate  \
# ARG        11.198         7.441        18933.9               191.032
# ARG        11.198         7.441        18933.9               191.032
# ARG        11.198         7.441        18933.9               191.032
# ARG        11.198         7.441        18933.9               191.032
# ARG        11.198         7.441        18933.9               191.032
# ..            ...           ...            ...                   ...
# ESP        19.436        13.799        34272.4                99.403
# ESP        19.436        13.799        34272.4                99.403
# ESP        19.436        13.799        34272.4                99.403
# ESP        19.436        13.799        34272.4                99.403
# ESP        19.436        13.799        34272.4                99.403
#
#     diabetes_prevalence handwashing_facilities hospital_beds_per_thousand  \
# ARG                 5.5                    NaN                          5
# ARG                 5.5                    NaN                          5
# ARG                 5.5                    NaN                          5
# ARG                 5.5                    NaN                          5
# ARG                 5.5                    NaN                          5
# ..                  ...                    ...                        ...
# ESP                7.17                    NaN                       2.97
# ESP                7.17                    NaN                       2.97
# ESP                7.17                    NaN                       2.97
# ESP                7.17                    NaN                       2.97
# ESP                7.17                    NaN                       2.97
#
#     life_expectancy human_development_index  \
# ARG           76.67                   0.825
# ARG           76.67                   0.825
# ARG           76.67                   0.825
# ARG           76.67                   0.825
# ARG           76.67                   0.825
# ..              ...                     ...
# ESP           83.56                   0.891
# ESP           83.56                   0.891
# ESP           83.56                   0.891
# ESP           83.56                   0.891
# ESP           83.56                   0.891
#
#                                                   data extreme_poverty  \
# ARG  {'date': '2020-01-01', 'total_tests': 4.0, 'ne...             0.6
# ARG  {'date': '2020-01-02', 'total_tests': 14.0, 'n...             0.6
# ARG  {'date': '2020-01-03', 'total_tests': 19.0, 'n...             0.6
# ARG  {'date': '2020-01-04', 'total_tests': 31.0, 'n...             0.6
# ARG  {'date': '2020-01-05', 'total_tests': 41.0, 'n...             0.6
# ..                                                 ...             ...
# ESP  {'date': '2021-01-14', 'total_cases': 2211967....               1
# ESP  {'date': '2021-01-15', 'total_cases': 2252164....               1
# ESP  {'date': '2021-01-16', 'total_cases': 2252164....               1
# ESP  {'date': '2021-01-17', 'total_cases': 2252164....               1
# ESP  {'date': '2021-01-18', 'total_cases': 2336451....               1
#
#     female_smokers male_smokers
# ARG           16.2         27.7
# ARG           16.2         27.7
# ARG           16.2         27.7
# ARG           16.2         27.7
# ARG           16.2         27.7
# ..             ...          ...
# ESP           27.4         31.4
# ESP           27.4         31.4
# ESP           27.4         31.4
# ESP           27.4         31.4
# ESP           27.4         31.4
#
# [1741 rows x 18 columns]

# %%
import json
second = pd.json_normalize(json.loads(first.to_json(orient="records")))
second
# Out:
#           continent   location  population  population_density  median_age  \
# 0     South America  Argentina  45195777.0              16.177        31.9
# 1     South America  Argentina  45195777.0              16.177        31.9
# 2     South America  Argentina  45195777.0              16.177        31.9
# 3     South America  Argentina  45195777.0              16.177        31.9
# 4     South America  Argentina  45195777.0              16.177        31.9
# ...             ...        ...         ...                 ...         ...
# 1736         Europe      Spain  46754783.0              93.105        45.5
# 1737         Europe      Spain  46754783.0              93.105        45.5
# 1738         Europe      Spain  46754783.0              93.105        45.5
# 1739         Europe      Spain  46754783.0              93.105        45.5
# 1740         Europe      Spain  46754783.0              93.105        45.5
#
#       aged_65_older  aged_70_older  gdp_per_capita  cardiovasc_death_rate  \
# 0            11.198          7.441       18933.907                191.032
# 1            11.198          7.441       18933.907                191.032
# 2            11.198          7.441       18933.907                191.032
# 3            11.198          7.441       18933.907                191.032
# 4            11.198          7.441       18933.907                191.032
# ...             ...            ...             ...                    ...
# 1736         19.436         13.799       34272.360                 99.403
# 1737         19.436         13.799       34272.360                 99.403
# 1738         19.436         13.799       34272.360                 99.403
# 1739         19.436         13.799       34272.360                 99.403
# 1740         19.436         13.799       34272.360                 99.403
#
#       diabetes_prevalence  ...  data.new_vaccinations_smoothed_per_million  \
# 0                    5.50  ...                                         NaN
# 1                    5.50  ...                                         NaN
# 2                    5.50  ...                                         NaN
# 3                    5.50  ...                                         NaN
# 4                    5.50  ...                                         NaN
# ...                   ...  ...                                         ...
# 1736                 7.17  ...                                      1433.0
# 1737                 7.17  ...                                      1500.0
# 1738                 7.17  ...                                      1501.0
# 1739                 7.17  ...                                      1502.0
# 1740                 7.17  ...                                      1503.0
#
#       data.new_vaccinations  data.weekly_icu_admissions  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 1736                94548.0                         NaN
# 1737                92764.0                         NaN
# 1738                    NaN                         NaN
# 1739                    NaN                         NaN
# 1740                    NaN                         NaN
#
#       data.weekly_icu_admissions_per_million  data.weekly_hosp_admissions  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 1736                                     NaN                          NaN
# 1737                                     NaN                          NaN
# 1738                                     NaN                          NaN
# 1739                                     NaN                          NaN
# 1740                                     NaN                          NaN
#
#       data.weekly_hosp_admissions_per_million  data.icu_patients  \
# 0                                         NaN                NaN
# 1                                         NaN                NaN
# 2                                         NaN                NaN
# 3                                         NaN                NaN
# 4                                         NaN                NaN
# ...                                       ...                ...
# 1736                                      NaN                NaN
# 1737                                      NaN                NaN
# 1738                                      NaN                NaN
# 1739                                      NaN                NaN
# 1740                                      NaN                NaN
#
#      data.icu_patients_per_million  data.hosp_patients  \
# 0                              NaN                 NaN
# 1                              NaN                 NaN
# 2                              NaN                 NaN
# 3                              NaN                 NaN
# 4                              NaN                 NaN
# ...                            ...                 ...
# 1736                           NaN                 NaN
# 1737                           NaN                 NaN
# 1738                           NaN                 NaN
# 1739                           NaN                 NaN
# 1740                           NaN                 NaN
#
#       data.hosp_patients_per_million
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1736                             NaN
# 1737                             NaN
# 1738                             NaN
# 1739                             NaN
# 1740                             NaN
#
# [1741 rows x 54 columns]

# %%
second.columns.value_counts()
# Out:
# data.new_cases                                1
# data.hosp_patients_per_million                1
# life_expectancy                               1
# data.new_cases_smoothed                       1
# data.new_vaccinations                         1
# data.new_deaths_per_million                   1
# diabetes_prevalence                           1
# hospital_beds_per_thousand                    1
# female_smokers                                1
# data.icu_patients                             1
# data.weekly_icu_admissions_per_million        1
# male_smokers                                  1
# population                                    1
# data.total_tests                              1
# data.new_tests_smoothed                       1
# data.new_cases_smoothed_per_million           1
# data.total_deaths                             1
# data.total_cases_per_million                  1
# location                                      1
# data.total_vaccinations_per_hundred           1
# data.total_tests_per_thousand                 1
# data.weekly_icu_admissions                    1
# data.new_vaccinations_smoothed                1
# data.icu_patients_per_million                 1
# data.hosp_patients                            1
# data.weekly_hosp_admissions                   1
# human_development_index                       1
# data.new_cases_per_million                    1
# data.total_vaccinations                       1
# extreme_poverty                               1
# data.new_deaths_smoothed_per_million          1
# data.positive_rate                            1
# median_age                                    1
# data.reproduction_rate                        1
# data.date                                     1
# data.new_tests_per_thousand                   1
# data.total_cases                              1
# data.total_deaths_per_million                 1
# data.new_tests                                1
# data.stringency_index                         1
# data.new_deaths_smoothed                      1
# population_density                            1
# data.tests_per_case                           1
# aged_65_older                                 1
# cardiovasc_death_rate                         1
# data.new_deaths                               1
# data.weekly_hosp_admissions_per_million       1
# handwashing_facilities                        1
# gdp_per_capita                                1
# continent                                     1
# data.tests_units                              1
# data.new_tests_smoothed_per_thousand          1
# aged_70_older                                 1
# data.new_vaccinations_smoothed_per_million    1
# dtype: int64

# %%
second["data.date"]
# Out:
# 0       2020-01-01
# 1       2020-01-02
# 2       2020-01-03
# 3       2020-01-04
# 4       2020-01-05
#            ...
# 1736    2021-01-14
# 1737    2021-01-15
# 1738    2021-01-16
# 1739    2021-01-17
# 1740    2021-01-18
# Name: data.date, Length: 1741, dtype: object

# %%
data_covid = covid.loc[:, ['data']]
data_covid = extract_dict_values(df_name=data_covid, column_df='data')
data_covid
# Out:
#            date  total_tests  new_tests  total_tests_per_thousand  \
# 0    2020-01-01          4.0        4.0                     0.000
# 1    2020-01-02         14.0       10.0                     0.000
# 2    2020-01-03         19.0        5.0                     0.000
# 3    2020-01-04         31.0       12.0                     0.001
# 4    2020-01-05         41.0       10.0                     0.001
# ..          ...          ...        ...                       ...
# 348  2021-01-14          NaN        NaN                       NaN
# 349  2021-01-15          NaN        NaN                       NaN
# 350  2021-01-16          NaN        NaN                       NaN
# 351  2021-01-17          NaN        NaN                       NaN
# 352  2021-01-18          NaN        NaN                       NaN
#
#      new_tests_per_thousand    tests_units  stringency_index  \
# 0                       0.0  people tested               0.0
# 1                       0.0  people tested               0.0
# 2                       0.0  people tested               0.0
# 3                       0.0  people tested               0.0
# 4                       0.0  people tested               0.0
# ..                      ...            ...               ...
# 348                     NaN            NaN              71.3
# 349                     NaN            NaN              71.3
# 350                     NaN            NaN              71.3
# 351                     NaN            NaN              71.3
# 352                     NaN            NaN               NaN
#
#      new_tests_smoothed  new_tests_smoothed_per_thousand  total_cases  ...  \
# 0                   NaN                              NaN          NaN  ...
# 1                   NaN                              NaN          NaN  ...
# 2                   NaN                              NaN          NaN  ...
# 3                   NaN                              NaN          NaN  ...
# 4                   NaN                              NaN          NaN  ...
# ..                  ...                              ...          ...  ...
# 348                 NaN                              NaN    2211967.0  ...
# 349                 NaN                              NaN    2252164.0  ...
# 350                 NaN                              NaN    2252164.0  ...
# 351                 NaN                              NaN    2252164.0  ...
# 352                 NaN                              NaN    2336451.0  ...
#
#      new_vaccinations_smoothed_per_million  new_vaccinations  \
# 0                                      NaN               NaN
# 1                                      NaN               NaN
# 2                                      NaN               NaN
# 3                                      NaN               NaN
# 4                                      NaN               NaN
# ..                                     ...               ...
# 348                                 1433.0           94548.0
# 349                                 1500.0           92764.0
# 350                                 1501.0               NaN
# 351                                 1502.0               NaN
# 352                                 1503.0               NaN
#
#      weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                      NaN                                NaN
# 1                      NaN                                NaN
# 2                      NaN                                NaN
# 3                      NaN                                NaN
# 4                      NaN                                NaN
# ..                     ...                                ...
# 348                    NaN                                NaN
# 349                    NaN                                NaN
# 350                    NaN                                NaN
# 351                    NaN                                NaN
# 352                    NaN                                NaN
#
#      weekly_hosp_admissions  weekly_hosp_admissions_per_million  icu_patients  \
# 0                       NaN                                 NaN           NaN
# 1                       NaN                                 NaN           NaN
# 2                       NaN                                 NaN           NaN
# 3                       NaN                                 NaN           NaN
# 4                       NaN                                 NaN           NaN
# ..                      ...                                 ...           ...
# 348                     NaN                                 NaN           NaN
# 349                     NaN                                 NaN           NaN
# 350                     NaN                                 NaN           NaN
# 351                     NaN                                 NaN           NaN
# 352                     NaN                                 NaN           NaN
#
#      icu_patients_per_million  hosp_patients  hosp_patients_per_million
# 0                         NaN            NaN                        NaN
# 1                         NaN            NaN                        NaN
# 2                         NaN            NaN                        NaN
# 3                         NaN            NaN                        NaN
# 4                         NaN            NaN                        NaN
# ..                        ...            ...                        ...
# 348                       NaN            NaN                        NaN
# 349                       NaN            NaN                        NaN
# 350                       NaN            NaN                        NaN
# 351                       NaN            NaN                        NaN
# 352                       NaN            NaN                        NaN
#
# [1741 rows x 37 columns]
